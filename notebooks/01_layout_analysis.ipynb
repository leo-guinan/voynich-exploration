# %% [markdown]
# # 01: Layout Analysis
#
# **Goal**: Quantify layout characteristics of the manuscript.
#
# Metrics:
# - Lines per page
# - Words per line
# - Margins
# - Text density vs illustration density
#
# Output: `data/derived/stats/layout_summary.csv`

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt

# Set paths
DATA_DIR = Path('../data')
IMAGES_DIR = DATA_DIR / 'raw/yale/images'
METADATA_DIR = DATA_DIR / 'raw/transcriptions/metadata'
OUTPUT_DIR = DATA_DIR / 'derived/stats'
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
